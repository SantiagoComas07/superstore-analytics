# %% [markdown]
# sales performance - profit analysis - customer analysis - products

# %% [markdown]
# PREGUNTAS
# GENERALES
# ¿Cuál es el total de ventas del período analizado?
# ¿Cuál es el margen de utilidad?
# ¿Cuál es la tendencia de ventas a través del tiempo?
# SEGMENTO
# ¿Qué categorías generan mayores ventas?
# ¿Qué regiones venden más?
# ¿Qué ciudades generan mayores ingresos?
# ¿Quiénes son los clientes más valiosos?
# ¿Cómo cambia el comportamiento de ventas según la temporada del año?
# ANALISIS DE RENTABILIDAD
# ¿Qué productos generan mayor beneficio?
# ¿Qué categorías tienen mejor margen de utilidad?
# ¿Qué factores influyen en la rentabilidad?
